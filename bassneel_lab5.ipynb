# %% [markdown]
# # Lab 5
#
# [![image](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/giswqs/geosdemo/blob/master/docs/labs/lab5.ipynb)
#
# ## Submission instructions
#
# 1. Download the notebook from https://geosdemo.gishub.org/labs/lab5
# 2. Complete the lab questions
# 3. Restart Kernel and Run All Cells
# 4. Upload the notebook to your GitHub repository
# 5. Make sure the notebook has an `Open In Colab` badge. Click on the badge to make sure your notebook can be opened in Colab.
# 6. Submit the link to the notebook on your GitHub repository to Canvas

# %%
from datetime import datetime

now = datetime.now()
print(f"Submitted time: {now}")
# Out:
# Submitted time: 2023-03-24 04:14:51.101083

# %% [markdown]
# ## Question 1
#
# **Person:** Use a dictionary to store information about a person you know. Store their first name, last name, age, and the city in which they live. You should have keys such as first_name, last_name, age, and city. Print each piece of information stored in your dictionary.

# %%
user_1 = {'first_name': 'Bryson', 'last_name': 'Hundley', 'age': '24', 'city': 'Dallas'}
for value in user_1.values():
  print(value)
# Out:
# Bryson
# Hundley
# 24
# Dallas

# %% [markdown]
# ## Question 2
#
# **Favorite Numbers:** Use a dictionary to store people’s favorite numbers. Think of five names, and use them as keys in your dictionary. Think of a favorite number for each person, and store each as a value in your dictionary. Print each person’s name and their favorite number. For even more fun, poll a few friends and get some actual data for your program.

# %%
fave_numb = {'Bruno': '8', 'Cristiano': '7', 'Marcus': '10', 'David': '1', 'Lisandro': '6'}
for key, value in fave_numb.items():
  print(key, value)
# Out:
# Bruno 8
# Cristiano 7
# Marcus 10
# David 1
# Lisandro 6

# %% [markdown]
# ## Question 3
#
# **Glossary:** A Python dictionary can be used to model an actual dictionary. However, to avoid confusion, let’s call it a glossary.
#
# - Think of five programming words you’ve learned about in the previous chapters. Use these words as the keys in your glossary, and store their meanings as values.
# - Print each word and its meaning as neatly formatted output. You might print the word followed by a colon and then its meaning, or print the word on one line and then print its meaning indented on a second line. Use the newline character (\n) to insert a blank line between each word-meaning pair in your output.

# %%
glossary = {
    'class': 'Classes provide a means of bundling data and functionality together.',
    'list': 'Lists are used to store multiple items in a single variable.',
    'for loop': 'For loops are used for iterating over a sequence.',
    'string': 'Strings are an immutable sequence of characters',
    'tuple': 'Tuples are an immutable sequence of objects',
    }
print(f"Class:\n{glossary['class']}\n")
print(f"List:\n{glossary['list']}\n")
print(f"For Loop:\n{glossary['for loop']}\n")
print(f"String:\n{glossary['string']}\n")
print(f"Tuple:\n{glossary['tuple']}\n")
# Out:
# Class:
# Classes provide a means of bundling data and functionality together.
#
# List:
# Lists are used to store multiple items in a single variable.
#
# For Loop:
# For loops are used for iterating over a sequence.
#
# String:
# Strings are an immutable sequence of characters
#
# Tuple:
# Tuples are an immutable sequence of objects

# %% [markdown]
# ## Question 4
#
# **Glossary 2:** Now that you know how to loop through a dictionary, clean up the code from Question 3 by replacing your series of print() calls with a loop that runs through the dictionary’s keys and values. When you’re sure that your loop works, add five more Python terms to your glossary. When you run your program again, these new words and meanings should automatically be included in the output.

# %%
glossary = {
    'class': 'Classes provide a means of bundling data and functionality together.',
    'list': 'Lists are used to store multiple items in a single variable.',
    'for loop': 'For loops are used for iterating over a sequence.',
    'string': 'Strings are an immutable sequence of characters',
    'tuple': 'Tuples are an immutable sequence of objects',
    'dictionary': 'Dictionaries are associate arrays used to structure data.',
    'variable': 'Variables are containers for data values.',
    'while loop': 'While Loops are used to execute a block of statements repeatedly until a given condition is satisfied.',
    'slice': 'Slice is a function used to slice and return objects in a sequence.',
    'if statemen': 'If Statements are conditional statements that are used to determine whether a block of code will be executed or not.',
    }
for key, value in glossary.items():
  print(f'{key.title()}:\n{value}\n')
# Out:
# Class:
# Classes provide a means of bundling data and functionality together.
#
# List:
# Lists are used to store multiple items in a single variable.
#
# For Loop:
# For loops are used for iterating over a sequence.
#
# String:
# Strings are an immutable sequence of characters
#
# Tuple:
# Tuples are an immutable sequence of objects
#
# Dictionary:
# Dictionaries are associate arrays used to structure data.
#
# Variable:
# Variables are containers for data values.
#
# While Loop:
# While Loops are used to execute a block of statements repeatedly until a given condition is satisfied.
#
# Slice:
# Slice is a function used to slice and return objects in a sequence.
#
# If Statemen:
# If Statements are conditional statements that are used to determine whether a block of code will be executed or not.

# %% [markdown]
# ## Question 5
#
# **Rivers:** Make a dictionary containing three major rivers and the country each river runs through. One key-value pair might be 'nile': 'egypt'.
#
# - Use a loop to print a sentence about each river, such as _The Nile runs through Egypt._
# - Use a loop to print the name of each river included in the dictionary.
# - Use a loop to print the name of each country included in the dictionary.

# %%
rivers = {
    'congo': 'Democratic Republic of the Congo',
    'amazon': 'Brazil',
    'nile': 'Egypt',
    }
for key, value in rivers.items():
  print(f'\t{key.title()}\n\t{value}\n')
  print(f'The {key.title()} River run through {value}.\n')
# Out:
# 	Congo
# 	Democratic Republic of the Congo
#
# The Congo River run through Democratic Republic of the Congo.
#
# 	Amazon
# 	Brazil
#
# The Amazon River run through Brazil.
#
# 	Nile
# 	Egypt
#
# The Nile River run through Egypt.

# %% [markdown]
# ## Question 6
#
# **Cities:** Make a dictionary called `cities`. Use the names of three cities as keys in your dictionary. Create a dictionary of information about each city and include the country that the city is in, its approximate population, and one fact about that city. The keys for each city’s dictionary should be something like `country`, `population`, and `fact`. Print the name of each city and all of the information you have stored about it.

# %%
cities = {
    'Manchester': {
        'country': 'England',
        'population': '553,230',
        'fact': 'The first atom was split in here.',
        },
    'Munich': {
        'country': 'Germany',
        'population': '1.472 million',
        'fact': 'The oldest building here is a toilet.',
        },
    'Barcelona': {
        'country': 'Spain',
        'population': '1.62 million',
        'fact': 'This is the capital of Catalonia.',
        },
    }
for city, city_info in cities.items():
  print(f'City: {city}')
  country = city_info['country']
  population = city_info['population']
  fact = city_info['fact']

  print(f"\tCountry: {country}\n\tPopulation: {population}\n\tFact: {fact}")
# Out:
# City: Manchester
# 	Country: England
# 	Population: 553,230
# 	Fact: The first atom was split in here.
# City: Munich
# 	Country: Germany
# 	Population: 1.472 million
# 	Fact: The oldest building here is a toilet.
# City: Barcelona
# 	Country: Spain
# 	Population: 1.62 million
# 	Fact: This is the capital of Catalonia.

# %% [markdown]
# ## Question 7
#
# **Rental Car:** Write a program that asks the user what kind of rental car they would like. Print a message about that car, such as “Let me see if I can find you a Subaru.”

# %%
brand = input("Enter the brand of car you would like to rent: ")
print(f"Let me see if I can find you a {brand}.")
# Out:
# Enter the brand of car you would like to rent: chevy
# Let me see if I can find you a chevy.

# %% [markdown]
# ## Question 8
#
# **Restaurant Seating:** Write a program that asks the user how many people are in their dinner group. If the answer is more than eight, print a message saying they’ll have to wait for a table. Otherwise, report that their table is ready.

# %%
how_many = input("How many people will be in your party today?\n\tYour answer: ")
how_many = int(how_many)

if how_many > 8:
  print("\nWe apologize, but it's gonna be about a 30 minute wait before we're able to seat your party.")
else:
  print("\nWe have a table ready for you! Right this way.")
# Out:
# How many people will be in your party today?
# 	Your answer: 9
#
# We apologize, but it's gonna be about a 30 minute wait before we're able to seat your party.

# %% [markdown]
# ## Question 9
#
# **Multiples of Ten:** Ask the user for a number, and then report whether the number is a multiple of 10 or not.

# %%
number = input("Enter a number, and I'll tell you if it's a multiple of 10: ")
number = int(number)

if number % 10 == 10:
  print(f"\nThe number {number} is a multiple of 10!")
else:
  print(f"\nThe number {number} is not a multiple of 10.")
# Out:
# Enter a number, and I'll tell you if it's a multiple of 10: 34
#
# The number 34 is not a multiple of 10.

# %% [markdown]
# ## Question 10
#
# **Pizza Toppings:** Write a loop that prompts the user to enter a series of pizza toppings until they enter a 'quit' value. As they enter each topping, print a message saying you’ll add that topping to their pizza.

# %%
topping = "What toppings would you like on your pizza?"
topping += "\nTell me 'done' when you've finished selecting\n"

message = ""
while message != 'done':
  message = input(topping)
  if message == 'done':
    break
# Out:
# What toppings would you like on your pizza?
# Tell me 'done' when you've finished selecting
# pepperoni
# What toppings would you like on your pizza?
# Tell me 'done' when you've finished selecting
# dont
# What toppings would you like on your pizza?
# Tell me 'done' when you've finished selecting
# done

# %% [markdown]
# ## Question 11
#
# **Message:** Write a function called `display_message()` that prints one sentence telling everyone what you are learning about in this chapter. Call the function, and make sure the message displays correctly.

# %%
def display_message():
    """Display subject of this chapter."""
    print("In Chapter 8, we are going to cover how to define and run functions.")

display_message()
# Out:
# In Chapter 8, we are going to cover how to define and run functions.

# %% [markdown]
# ## Question 12
#
# **Favorite Book:** Write a function called `favorite_book()` that accepts one parameter, title. The function should print a message, such as `One of my favorite books is Alice in Wonderland`. Call the function, making sure to include a book title as an argument in the function call.

# %%
def favorite_book(book_title):
  """Display favorite book."""
  print(f"One of my favorite books is {book_title}!")

favorite_book('The Communist Manifesto')
# Out:
# One of my favorite books is The Communist Manifesto!

# %% [markdown]
# ## Question 13
#
# **T-Shirt:** Write a function called `make_shirt()` that accepts a size and the text of a message that should be printed on the shirt. The function should print a sentence summarizing the size of the shirt and the message printed on it.
#
# Call the function once using positional arguments to make a shirt. Call the function a second time using keyword arguments.

# %%
def make_shirt(size, logo):
  """Display shirt size and logo."""
  print(f"I wear a {size} and I want it printed with a {logo} logo.")
make_shirt('large', 'Manchester United')

def make_shirt(size, logo):
  """Display shirt size and logo."""
  print(f"I wear a {size} and I want it printed with a {logo} logo.")
make_shirt(size = 'large', logo = 'Manchester United')
# Out:
# I wear a large and I want it printed with a Manchester United logo.
# I wear a large and I want it printed with a Manchester United logo.

# %% [markdown]
# ## Question 14
#
# **Large Shirts:** Modify the `make_shirt()` function so that shirts are large by default with a message that reads _I love Python_. Make a large shirt and a medium shirt with the default message, and a shirt of any size with a different message.

# %%
def make_shirt(message, size = 'large'):
  """Display shirt size and logo."""
  print(f'I wear a {size} and I want message to read, "{message}"')
make_shirt(message = 'I love Python!')

def make_shirt(message, size = 'large'):
  """Display shirt size and logo."""
  print(f'I wear a {size} and I want message to read, "{message}"')
make_shirt(message = 'I love Python!', size = 'medium')
# Out:
# I wear a large and I want message to read, "I love Python!"
# I wear a medium and I want message to read, "I love Python!"

# %% [markdown]
# ## Question 15
#
# **Cities:** Write a function called `describe_city()` that accepts the name of a city and its country. The function should print a simple sentence, such as `Reykjavik is in Iceland`. Give the parameter for the country a default value. Call your function for three different cities, at least one of which is not in the default country.

# %%
def describe_city(country, city = 'Reykjavic'):
  """Describe city."""
  print(f"{city} is in {country}.")
describe_city('Iceland')
describe_city(country = 'England', city = 'London')
describe_city(country = 'Japan', city = 'Tokyo')
# Out:
# Reykjavic is in Iceland.
# London is in England.
# Tokyo is in Japan.

# %% [markdown]
# ## Question 16
#
# **City Names:** Write a function called `city_country()` that takes in the name of a city and its country. The function should return a string formatted like this:
#
# ```text
# Santiago, Chile
# ```
#
# Call your function with at least three city-country pairs, and print the values that are returned.

# %%
def city_country(city, country):
  """Display city and country."""
  locale = f'{city}, {country}'
  return locale.title()
london = city_country('london', 'England')
turin = city_country('Turin', 'Italy')
athens = city_country('Athens', 'Greece')
print(london)
print(turin)
print(athens)
# Out:
# London, England
# Turin, Italy
# Athens, Greece

# %% [markdown]
# ## Question 17
#
# **Album:** Write a function called `make_album()` that builds a dictionary describing a music album. The function should take in an artist name and an album title, and it should return a dictionary containing these two pieces of information. Use the function to make three dictionaries representing different albums. Print each return value to show that the dictionaries are storing the album information correctly.
#
# Use None to add an optional parameter to make_album() that allows you to store the number of songs on an album. If the calling line includes a value for the number of songs, add that value to the album’s dictionary. Make at least one new function call that includes the number of songs on an album.

# %%
def make_album(artist, album_title):
  """Display artist and album title"""
  album = {'artist': artist, 'album_title': album_title}
  return album
music = make_album("Still Woozy", "If This Isn't Nice, I Don't Know What Is")
print(music)

def make_album(artist, album_title, song_count = None):
  """Display artist and album title"""
  album = {'artist': artist, 'album_title': album_title}
  if song_count:
    album['song_count'] = song_count
  return album
music = make_album("Still Woozy", "If This Isn't Nice, I Don't Know What Is", song_count = 13)
print(music)
# Out:
# {'artist': 'Still Woozy', 'album_title': "If This Isn't Nice, I Don't Know What Is"}
# {'artist': 'Still Woozy', 'album_title': "If This Isn't Nice, I Don't Know What Is", 'song_count': 13}

# %% [markdown]
# ## Question 18
#
# **User Albums:** Start with your program from Question 17. Write a `while` loop that allows users to enter an album’s artist and title. Once you have that information, call `make_album()` with the user’s input and print the dictionary that’s created. Be sure to include a quit value in the `while` loop.

# %%
def make_album(artist, album_title):
  """Display artist and album title"""
  album = f"{album_title.title()} by {artist.title()}"
  return album

while True:
  print("What is your favorite album?")
  print("(enter 'q' at any time to quit)")

  a_artist = input("Artist name: ")
  if a_artist == 'q':
    break
  
  a_album = input("Album title: ")
  if a_album == 'q':
    break
  
  format_album = make_album(a_artist, a_album)
  print(f"\n\t{format_album} is a great album!\n")
# Out:
# What is your favorite album?
# (enter 'q' at any time to quit)
# Artist name: Meteora
# Album title: q

# %% [markdown]
# ## Question 19
#
# **Messages:** Make a list containing a series of short text messages. Pass the list to a function called `show_messages()`, which prints each text message.

# %%
def show_messages(messages):
    """Print the messages in a list."""
    for message in messages:
        text = f"{message}"
        print(text)

text_msg = ['Wyd?', 'What did you put for question 19???', 'betttttt']
show_messages(text_msg)
# Out:
# Wyd?
# What did you put for question 19???
# betttttt

# %% [markdown]
# ## Question 20
#
# **Sending Messages:** Start with a copy of your program from Question 19. Write a function called `send_messages()` that prints each text message and moves each message to a new list called `sent_messages` as it’s printed. After calling the function, print both of your lists to make sure the messages were moved correctly.

# %%
def show_messages(text_msg, sent_messages):
    """Print the messages in a list."""
    while text_msg:
      current_text = text_msg.pop(0)
      print(current_text)
      sent_messages.append(current_text)

text_msg = ['Wyd?', 'What did you put for question 19???', 'betttttt']
sent_messages = []

show_messages(text_msg, sent_messages)
print(sent_messages)
# Out:
# Wyd?
# What did you put for question 19???
# betttttt
# ['Wyd?', 'What did you put for question 19???', 'betttttt']

# %% [markdown]
# ## Question 21
#
# **Learning Python:** Open a blank file in your text editor and write a few lines summarizing what you’ve learned about Python so far. Start each line with the phrase _In Python you can. . .._ Save the file as _learning_python.txt_ in the same directory as your exercises from this chapter. Write a program that reads the file and prints what you wrote three times. Print the contents once by reading in the entire file, once by looping over the file object, and once by storing the lines in a list and then working with them outside the _with_ block.

# %%
print("\tRead")
with open("/content/learning_python.txt", "r") as file_object:
  contents = file_object.read()
print(contents)
print('...')
print("\tLine")
with open("/content/learning_python.txt", "r") as file_object:
  for line in file_object:
    print(line)
print('...')
print("\tList")
with open("/content/learning_python.txt", "r") as file_object:
  lines = file_object.readlines()

python_string = ''
for line in lines:
  python_string += line

print(python_string[0:])
# Out:
# 	Read
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-22-c5b076a456b6> in <module>
#       1 print("\tRead")
# ----> 2 with open("/content/learning_python.txt", "r") as file_object:
#       3   contents = file_object.read()
#       4 print(contents)
#       5 print('...')
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/learning_python.txt'

# %% [markdown]
# ## Question 22
#
# **Learning C:** You can use the replace() method to replace any word in a string with a different word. Here’s a quick example showing how to replace 'dog' with 'cat' in a sentence:
#
# ```text
# message = "I really like dogs."
# message.replace('dog', 'cat')
# 'I really like cats.'
# ```
#
# Read in each line from the file you just created, _learning_python.txt_, and replace the word _Python_ with the name of another language, such as _C_. Print each modified line to the screen.

# %%
with open("/content/learning_python.txt", "r") as file_object:
  lines = file_object.readlines()

python_string = ''
for line in lines:
  python_string += line

replace_string = python_string.replace('Python', 'C')
print(replace_string)

# %% [markdown]
# ## Question 23
#
# **Guest:** Write a program that prompts the user for their name. When they respond, write their name to a file called guest.txt.

# %%
full_name = input("Enter your full name: ")

filename = '/content/guest.txt'

with open(filename, 'w') as file_object:
    file_object.write(f"{full_name.title()}")

# %% [markdown]
# ## Question 24
#
# **Guest Book:** Write a while loop that prompts users for their name. When they enter their name, print a greeting to the screen and add a line recording their visit in a file called guest_book.txt. Make sure each entry appears on a new line in the file.

# %%
guests = []
while True:
  print("Enter your full name:")
  print("(enter 'q' at any time to quit)")

  guest = input("")
  if guest == 'q':
    break
  guests.append(guest)

filename = '/content/guest_book.txt'

with open(filename, 'w') as file_object:
  for guest in guests:
    file_object.write(f"{guest.title()}\n")

# %% [markdown]
# ## Question 25
#
# **Programming Poll:** Write a while loop that asks people why they like programming. Each time someone enters a reason, add their reason to a file that stores all the responses.

# %%
print("Why do you like programming?")
print("(Enter 'q' to quit)")

responses = []

while True:
  reason = input("\nYour response: ")
  if reason == 'q':
    break
  responses.append(reason)

filename = '/content/poll.txt'

with open(filename, 'w') as file_object:
  file_object.write(f"{responses}")

# %% [markdown]
# ## Question 26
#
# **Addition:** One common problem when prompting for numerical input occurs when people provide text instead of numbers. When you try to convert the input to an int, you’ll get a ValueError. Write a program that prompts for two numbers. Add them together and print the result. Catch the ValueError if either input value is not a number, and print a friendly error message. Test your program by entering two numbers and then by entering some text instead of a number.

# %%
print("Give me two numbers, and I'll add them.")
print("Enter 'q' to quit.")

first_number = input("\nFirst number: ")
second_number = input("Second number: ")

try:
  answer = int(first_number) + int(second_number)
except ValueError:
  print("You cannot add strings!")
else:
  print(answer)

# %% [markdown]
# ## Question 27
#
# **Addition Calculator:** Wrap your code from Question 26 in a while loop so the user can continue entering numbers even if they make a mistake and enter text instead of a number.

# %%
print("Give me two numbers, and I'll add them.")
print("Enter 'q' to quit.")

while True:
    first_number = input("\nFirst number: ")
    if first_number == 'q':
        break
    second_number = input("Second number: ")
    if second_number == 'q':
        break
    try:
        answer = int(first_number) + int(second_number)
    except ValueError:
        print("You cannot add strings!")
    else:
        print(answer)

# %% [markdown]
# ## Question 28
#
# **Cats and Dogs:** Make two files, _cats.txt_ and _dogs.txt_. Store at least three names of cats in the first file and three names of dogs in the second file. Write a program that tries to read these files and print the contents of the file to the screen. Wrap your code in a `try-except` block to catch the `FileNotFound` error, and print a friendly message if a file is missing. Move one of the files to a different location on your system, and make sure the code in the `except` block executes properly.

# %%
dog_file = '/content/dogs.txt'
cat_file = '/content/cats.txt'

try:
    with open(dog_file) as dog_object:
      dogs = dog_object.readlines()
      print("Dogs:", dogs)
    with open(cat_file) as cat_object:
      cats = cat_object.readlines()
      print("Cats:", cats)
except FileNotFoundError as e:
    print(f"The file {e.filename.title()} was not found")

# %% [markdown]
# ## Question 29
#
# **Silent Cats and Dogs:** Modify your except block in Question 28 to fail silently if either file is missing.

# %%
dog_file = '/content/dogs.txt'
cat_file = '/content/cats.txt'

try:
    with open(dog_file) as dog_object:
      dogs = dog_object.readlines()
      print("Dogs:", dogs)
    with open(cat_file) as cat_object:
      cats = cat_object.readlines()
      print("Cats:", cats)
except FileNotFoundError as e:
    pass

# %% [markdown]
# ## Question 30
#
# **Common Words:** Visit Project Gutenberg (<https://gutenberg.org/>) and find a few texts you’d like to analyze. Download the text files for these works, or copy the raw text from your browser into a text file on your computer. You can use the `count()` method to find out how many times a word or phrase appears in a string. For example, the following code counts the number of times 'row' appears in a string:

# %%
line = "Row, row, row your boat"
line.count('row')

# %%
line.lower().count('row')

# %% [markdown]
# Notice that converting the string to lowercase using lower() catches all appearances of the word you’re looking for, regardless of how it’s formatted.
#
# Write a program that reads the files you found at Project Gutenberg and determines how many times the word `the` appears in each text. This will be an approximation because it will also count words such as `then` and `there`. Try counting `the`, with a space in the string, and see how much lower your count is.

# %%
great_gatsby = '/content/great_gatsby.txt'

print("\tThe Great Gatsby:")

with open(great_gatsby) as gatsby_object:
  gatsby = gatsby_object.read()
  gatsby = gatsby.replace('\n', ' ')

count = gatsby.count('the')
print(f"The characters 'the' appear consecutively {count} times in the book.")

count = gatsby.count(' the')
print(f"The characters 'the' appear consecutively at the beginning of a word {count} times in the book.")

count = gatsby.count('the ')
print(f"The characters 'the' appear consecutively at the end of a word {count} times in the book.")

count = gatsby.count(' the ')
print(f"The word 'the' appears {count} times in the book.\n")

heart_of_darkness = '/content/heart_of_darkness.txt'

print("\tHeart of Darkness:")

with open(heart_of_darkness) as darkness_object:
  darkness = darkness_object.read()
  darkness = darkness.replace('\n', ' ')

count = darkness.count('the')
print(f"The characters 'the' appear consecutively {count} times in the book.")

count = darkness.count(' the')
print(f"The characters 'the' appear consecutively at the beginning of a word {count} times in the book.")

count = darkness.count('the ')
print(f"The characters 'the' appear consecutively at the end of a word {count} times in the book.")

count = darkness.count(' the ')
print(f"The word 'the' appears {count} times in the book.\n")

monte_cristo = '/content/monte_cristo.txt'

print("\tThe Count of Monte Cristo:")

with open(monte_cristo) as cristo_object:
  cristo = cristo_object.read()
  cristo = cristo.replace('\n', ' ')

count = cristo.count('the')
print(f"The characters 'the' appear consecutively {count} times in the book.")

count = cristo.count(' the')
print(f"The characters 'the' appear consecutively at the beginning of a word {count} times in the book.")

count = cristo.count('the ')
print(f"The characters 'the' appear consecutively at the end of a word {count} times in the book.")

count = cristo.count(' the ')
print(f"The word 'the' appears {count} times in the book.")

# %%
# same but using a loop
books = {
    '/content/great_gatsby.txt': 'The Great Gatsby',
    '/content/heart_of_darkness.txt': 'Heart of Darkness',
    '/content/monte_cristo.txt': 'The Count of Monte Cristo'
}

for filename, title in books.items():
    print(f"\t{title}:")
    with open(filename) as book_object:
        book = book_object.read().replace('\n', ' ')
        count = book.count('the')
        print(f"The characters 'the' appear consecutively {count} times in the book.")
        count = book.count(' the')
        print(f"The characters 'the' appear consecutively at the beginning of a word {count} times in the book.")
        count = book.count('the ')
        print(f"The characters 'the' appear consecutively at the end of a word {count} times in the book.")
        count = book.count(' the ')
        print(f"The word 'the' appears {count} times in the book.\n")
